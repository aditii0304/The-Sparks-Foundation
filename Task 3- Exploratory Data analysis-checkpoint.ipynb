# %% [markdown]
# # Author- Aditi Tare

# %% [markdown]
# Task 3: Exploratory Data Analysis

# %%
#Importing libraries
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
import warnings
import seaborn as sb
warnings.filterwarnings('ignore')

# %%
# Reading the dataset
df=pd.read_csv("Sample.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# Data Analysis

# %%
#Exploratory data Analysis
plt.figure(figsize=(8,5))
sb.kdeplot(df['Sales'], color='Green', label='Sales', shade=True,bw=50)
sb.kdeplot(df['Profit'], color='Purple', label='Profit', shade=True,bw=50)
plt.xlim([-100,1000])
plt.legend()

# %% [markdown]
# Visualisation corelation matrix

# %%
#Numerical data
numerical_data=df.select_dtypes(exclude=[object])
print(numerical_data.shape)
# Out:
# (9994, 5)

# %%
#Finding the corelation of numerical data
corr_matrix=numerical_data.corr()

# %%
#Displaying the corelation matrix
corr_matrix
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
#Visualising the corelation matrix using heatmap
sb.heatmap(df.corr(), cmap='rocket_r',annot=True)

# %% [markdown]
# Data Visualisation

# %%
#plotting graph
df.hist(bins=50, figsize=(20,20))
plt.show()

# %% [markdown]
# Pairplot for analyze each column
# 1] Based on ship mode

# %%
#Based on ship mode
sb.pairplot(df,hue='Ship Mode')

# %% [markdown]
# Count plots

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
sb.countplot(x='Ship Mode',data=df, palette='tab10')
plt.title('Ship Mode', fontsize='30')
# Out:
# Text(0.5, 1.0, 'Ship Mode')

# %% [markdown]
# ship mode wise sales, profit, discount analysis

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df_shipmode=df.groupby(['Ship Mode'])[['Sales', 'Discount', 'Profit']].mean()

# %%
#1.sales 2.discount 3.profit
df_shipmode.plot.pie(subplots=True,figsize=(18,20), autopct='%1.1f%%', labels=df_shipmode.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000011E2C20B788>,
# ...
#       dtype=object)

# %% [markdown]
# 2]Based on category

# %%
#Based on category
sb.pairplot(df, hue='Category')

# %% [markdown]
# count plots

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
sb.countplot(x='Category',data=df, palette='tab10')
plt.title('Category', fontsize='30')
# Out:
# Text(0.5, 1.0, 'Category')

# %% [markdown]
# Category wise sales, discount and profit analysis

# %%
df_category=df.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
df_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
#1.sales 2.discount 3.profit
df_category.plot.pie(subplots=True,figsize=(18,20), autopct='%1.1f%%', labels=df_category.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000011E2C2718C8>,
# ...
#       dtype=object)

# %% [markdown]
# 3]Based on sub category

# %%
#Based on sub-category
sb.pairplot(df, hue='Sub-Category')

# %% [markdown]
# Count plots

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
plt.figure(figsize=(20,10))
sb.countplot(df['Sub-Category'])
plt.title('Sub-Category', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Sub-Category')

# %% [markdown]
# sub category wise sales, profit and discount analysis

# %%
df_sub_category=df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
df_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918

# %% [markdown]
# 1]Based on sales

# %%
plt.figure(figsize=(15,15))
plt.pie(df_sub_category['Sales'], autopct='%1.1f%%', labels=df_sub_category.index)
plt.title('Sub-category Wise Sales Analysis', fontsize=30)
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 2]Based on Discount

# %%
plt.figure(figsize=(15,15))
plt.pie(df_sub_category['Discount'], autopct='%1.1f%%', labels=df_sub_category.index)
plt.title('Sub-category Wise Discount Analysis', fontsize=30)
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 3]Based on profit

# %%
df_sub_category.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',
                                                               figsize=(15,7), label=['Avg Sales Price($)','Profit($)'])

# %% [markdown]
# 4]Based on Region

# %%
#Based on Region
sb.pairplot(df, hue='Region')

# %% [markdown]
# Count plots

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
sb.countplot(x='Region',data=df, palette='tab10')
plt.title('Region', fontsize='30')
# Out:
# Text(0.5, 1.0, 'Region')

# %% [markdown]
# Region wise sales, profit and discount analysis

# %%
df_region=df.groupby(['Region'])[['Sales', 'Discount', 'Profit']].mean()
df_region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.772661  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %%
#1.sales 2.discount 3.profit
df_region.plot.pie(subplots=True,figsize=(18,20), autopct='%1.1f%%', labels=df_region.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000011E31009A08>,
# ...
#       dtype=object)

# %% [markdown]
# 5]Based on segment

# %%
#Based on segment
sb.pairplot(df, hue='Segment')

# %% [markdown]
# Count plots

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
sb.countplot(x='Segment',data=df, palette='tab10')
plt.title('Segment', fontsize='30')
# Out:
# Text(0.5, 1.0, 'Segment')

# %% [markdown]
# Segment wise Profit, discount and sales analysis

# %%
df_segment=df.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
#1.sales 2.discount 3.profit
df_segment.plot.pie(subplots=True,figsize=(18,20), autopct='%1.1f%%', startangle=90, shadow=True, labels=df_segment.index)
plt.title('Segment wise profit , discount and sales')
# Out:
# Text(0.5, 1.0, 'Segment wise profit , discount and sales')

# %% [markdown]
# 6]Based on Quantity

# %%
#Based on Quantity
sb.pairplot(df, hue='Quantity')

# %% [markdown]
# Count plots

# %%
df['Quantity'].value_counts()
# Out:
# 3     2409
# 2     2402
# 5     1230
# 4     1191
# 1      899
# 7      606
# 6      572
# 9      258
# 8      257
# 10      57
# 11      34
# 14      29
# 13      27
# 12      23
# Name: Quantity, dtype: int64

# %%
sb.countplot(x='Quantity',data=df, palette='tab10')
plt.title('Quantity', fontsize='30')
# Out:
# Text(0.5, 1.0, 'Quantity')

# %% [markdown]
# Quality wise profit discount and sales analysis

# %%
df_quantity=df.groupby(['Quantity'])[['Sales', 'Discount', 'Profit']].mean()
df_quantity
# Out:
#                 Sales  Discount      Profit
# Quantity
# 1           59.234632  0.152959    8.276396
# 2          120.354488  0.154858   16.006831
# 3          175.201578  0.153329   23.667715
# 4          271.764059  0.157708   37.131310
# 5          337.936339  0.157146   40.257394
# 6          362.101960  0.166556   18.051517
# 7          395.888393  0.161980   56.579163
# 8          458.210802  0.171595   42.244342
# 9          498.083683  0.147946   68.557716
# 10         422.046737  0.190702   35.862404
# 11         463.896529  0.097059  126.275503
# 12         646.452522  0.113043   51.524609
# 13        1197.710704  0.157407  235.144481
# 14         452.826138  0.151724   93.931166

# %%
#1.sales 2.discount 3.profit
df_quantity.plot.pie(subplots=True,figsize=(20,20), autopct='%1.1f%%', 
                    pctdistance=0.69,startangle=90, shadow=True, labels=df_quantity.index)
plt.title('Quantity wise profit , discount and sales')
# Out:
# Text(0.5, 1.0, 'Quantity wise profit , discount and sales')

# %% [markdown]
# 7]Based on discount

# %%
#Based on discount
sb.pairplot(df, hue='Discount')

# %%
df['Discount'].value_counts()
# Out:
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: Discount, dtype: int64

# %%
sb.countplot(x='Discount',data=df, palette='tab10')
plt.title('Discount', fontsize='30')
# Out:
# Text(0.5, 1.0, 'Discount')

# %% [markdown]
# distribuition plotting sales, profit, quantity, discount

# %%
fig, axs= plt.subplots(ncols=2, nrows=2, figsize=(15,15))
sb.distplot(df['Sales'], color='red', ax=axs[0][0])
sb.distplot(df['Profit'], color='green', ax=axs[0][1])
sb.distplot(df['Quantity'], color='orange', ax=axs[1][0])
sb.distplot(df['Discount'], color='blue', ax=axs[1][1])
axs[0][0].set_title('Sales Distribution', fontsize=20)
axs[0][1].set_title('Profit Distribution', fontsize=20)
axs[1][0].set_title('quantity Distribution', fontsize=20)
axs[1][1].set_title('Discount Distribution', fontsize=20)
plt.show()

# %% [markdown]
# Deal Analysis

# %% [markdown]
# 1. State wise

# %%
df['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
df1=df['State'].value_counts()
df1.head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
df1.plot(kind='bar', figsize=(15,5))
plt.ylabel('frequency/ number of deals')
plt.xlabel('states')
plt.title('State wise dealings', fontsize=30)
plt.show()

# %%
df['State'].value_counts().mean()
# Out:
# 203.9591836734694

# %% [markdown]
# 2.City Wise

# %%
df2=df['City'].value_counts()
df2=df2.head(50)

# %%
df1.plot(kind='bar', figsize=(15,5))
plt.ylabel('frequency/ number of deals')
plt.xlabel('City')
plt.title('City wise dealings', fontsize=30)
plt.show()

# %%
df['City'].value_counts().mean()
# Out:
# 18.821092278719398

# %% [markdown]
# # Thank You
